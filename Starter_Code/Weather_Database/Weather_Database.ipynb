# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-90, 90, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 782

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url =f'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]  
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(), 
                         "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | joigny
# Processing Record 2 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | wamba
# Processing Record 7 of Set 1 | raudeberg
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | burica
# City not found. Skipping...
# Processing Record 10 of Set 1 | henties bay
# Processing Record 11 of Set 1 | yenagoa
# Processing Record 12 of Set 1 | victoria
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | salvador
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | baijiantan
# Processing Record 17 of Set 1 | brigantine
# Processing Record 18 of Set 1 | floro
# Processing Record 19 of Set 1 | kalmunai
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | cidreira
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | hobyo
# Processing Record 25 of Set 1 | sinnamary
# Processing Record 26 of Set 1 | vila velha
# Processing Record 27 of Set 1 | lagoa
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | marrakesh
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | porto novo
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | kavaratti
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | touros
# Processing Record 37 of Set 1 | luanda
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | berlevag
# Processing Record 41 of Set 1 | bojaya
# City not found. Skipping...
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | abu dhabi
# Processing Record 44 of Set 1 | quelimane
# Processing Record 45 of Set 1 | skibbereen
# Processing Record 46 of Set 1 | utica
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | alta floresta
# Processing Record 50 of Set 1 | cayenne
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | cabedelo
# Processing Record 3 of Set 2 | paita
# Processing Record 4 of Set 2 | storsteinnes
# Processing Record 5 of Set 2 | otavi
# Processing Record 6 of Set 2 | bonavista
# Processing Record 7 of Set 2 | takoradi
# Processing Record 8 of Set 2 | dingle
# Processing Record 9 of Set 2 | benghazi
# Processing Record 10 of Set 2 | olinda
# Processing Record 11 of Set 2 | bougouni
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | porosozero
# Processing Record 14 of Set 2 | contamana
# Processing Record 15 of Set 2 | adrar
# Processing Record 16 of Set 2 | mahibadhoo
# Processing Record 17 of Set 2 | sao joao da barra
# Processing Record 18 of Set 2 | sao filipe
# Processing Record 19 of Set 2 | kondinskoye
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | namibe
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | maldonado
# Processing Record 25 of Set 2 | saint anthony
# Processing Record 26 of Set 2 | saint-augustin
# Processing Record 27 of Set 2 | kondagaon
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 2 | port blair
# Processing Record 31 of Set 2 | yining
# Processing Record 32 of Set 2 | qarqin
# Processing Record 33 of Set 2 | bubaque
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 36 of Set 2 | sao miguel do araguaia
# Processing Record 37 of Set 2 | jijiga
# Processing Record 38 of Set 2 | margate
# Processing Record 39 of Set 2 | pudozh
# Processing Record 40 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 2 | holme
# Processing Record 42 of Set 2 | mocuba
# Processing Record 43 of Set 2 | caravelas
# Processing Record 44 of Set 2 | la palma
# Processing Record 45 of Set 2 | araouane
# Processing Record 46 of Set 2 | ust-koksa
# Processing Record 47 of Set 2 | mehamn
# Processing Record 48 of Set 2 | bereda
# Processing Record 49 of Set 2 | menongue
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | gamba
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | panaitolion
# Processing Record 5 of Set 3 | olafsvik
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | ilulissat
# Processing Record 8 of Set 3 | marsa matruh
# Processing Record 9 of Set 3 | bakchar
# Processing Record 10 of Set 3 | richards bay
# Processing Record 11 of Set 3 | northam
# Processing Record 12 of Set 3 | port elizabeth
# Processing Record 13 of Set 3 | sayyan
# Processing Record 14 of Set 3 | marienburg
# Processing Record 15 of Set 3 | sarkand
# Processing Record 16 of Set 3 | ponta pora
# Processing Record 17 of Set 3 | djibo
# Processing Record 18 of Set 3 | bo
# City not found. Skipping...
# Processing Record 19 of Set 3 | sebastian
# Processing Record 20 of Set 3 | trofors
# Processing Record 21 of Set 3 | xai-xai
# Processing Record 22 of Set 3 | turukhansk
# Processing Record 23 of Set 3 | carora
# Processing Record 24 of Set 3 | san rafael
# Processing Record 25 of Set 3 | manakara
# Processing Record 26 of Set 3 | severnyy
# Processing Record 27 of Set 3 | biskamzha
# Processing Record 28 of Set 3 | laguna
# Processing Record 29 of Set 3 | kochevo
# Processing Record 30 of Set 3 | praia
# Processing Record 31 of Set 3 | leskolovo
# Processing Record 32 of Set 3 | klaksvik
# Processing Record 33 of Set 3 | corrente
# Processing Record 34 of Set 3 | yelniki
# Processing Record 35 of Set 3 | saraland
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | kaltasy
# Processing Record 38 of Set 3 | lieksa
# Processing Record 39 of Set 3 | los andes
# Processing Record 40 of Set 3 | kayes
# Processing Record 41 of Set 3 | marawi
# Processing Record 42 of Set 3 | pafos
# Processing Record 43 of Set 3 | mazamari
# Processing Record 44 of Set 3 | khandbari
# Processing Record 45 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 46 of Set 3 | horta
# Processing Record 47 of Set 3 | shahr-e babak
# Processing Record 48 of Set 3 | bandarbeyla
# Processing Record 49 of Set 3 | moa
# Processing Record 50 of Set 3 | iqaluit
# Processing Record 1 of Set 4 | malakal
# Processing Record 2 of Set 4 | awassa
# Processing Record 3 of Set 4 | coihaique
# Processing Record 4 of Set 4 | grand gaube
# Processing Record 5 of Set 4 | havoysund
# Processing Record 6 of Set 4 | husavik
# Processing Record 7 of Set 4 | polignano a mare
# Processing Record 8 of Set 4 | the valley
# Processing Record 9 of Set 4 | onega
# Processing Record 10 of Set 4 | shostka
# Processing Record 11 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 4 | taoudenni
# Processing Record 13 of Set 4 | newport
# Processing Record 14 of Set 4 | sabya
# Processing Record 15 of Set 4 | isa khel
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | karasjok
# Processing Record 18 of Set 4 | ambanja
# Processing Record 19 of Set 4 | nagua
# Processing Record 20 of Set 4 | mayor pablo lagerenza
# Processing Record 21 of Set 4 | kruisfontein
# Processing Record 22 of Set 4 | muzhappilangad
# City not found. Skipping...
# Processing Record 23 of Set 4 | rudsar
# Processing Record 24 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 4 | bilma
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 4 | skjervoy
# Processing Record 29 of Set 4 | uyemskiy
# Processing Record 30 of Set 4 | oussouye
# Processing Record 31 of Set 4 | orebro
# Processing Record 32 of Set 4 | sistranda
# Processing Record 33 of Set 4 | nyagan
# Processing Record 34 of Set 4 | santa rosa
# Processing Record 35 of Set 4 | iralaya
# Processing Record 36 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 4 | chimore
# Processing Record 38 of Set 4 | carutapera
# Processing Record 39 of Set 4 | maunabo
# Processing Record 40 of Set 4 | eyl
# Processing Record 41 of Set 4 | salsomaggiore terme
# Processing Record 42 of Set 4 | kutum
# Processing Record 43 of Set 4 | aquiraz
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | villa bruzual
# Processing Record 46 of Set 4 | pangoa
# Processing Record 47 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 4 | safaga
# Processing Record 49 of Set 4 | grand-santi
# Processing Record 50 of Set 4 | umm lajj
# Processing Record 1 of Set 5 | acandi
# Processing Record 2 of Set 5 | malanje
# Processing Record 3 of Set 5 | gaur
# Processing Record 4 of Set 5 | budogoshch
# Processing Record 5 of Set 5 | salalah
# Processing Record 6 of Set 5 | himora
# City not found. Skipping...
# Processing Record 7 of Set 5 | polunochnoye
# Processing Record 8 of Set 5 | quatre cocos
# Processing Record 9 of Set 5 | bambous virieux
# Processing Record 10 of Set 5 | omboue
# Processing Record 11 of Set 5 | orlovka
# Processing Record 12 of Set 5 | opelika
# Processing Record 13 of Set 5 | igrim
# Processing Record 14 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 15 of Set 5 | mahanoro
# Processing Record 16 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 5 | muros
# Processing Record 18 of Set 5 | chipiona
# Processing Record 19 of Set 5 | dollar
# Processing Record 20 of Set 5 | la asuncion
# Processing Record 21 of Set 5 | spittal
# Processing Record 22 of Set 5 | vestmannaeyjar
# Processing Record 23 of Set 5 | riacho de santana
# Processing Record 24 of Set 5 | fontanka
# Processing Record 25 of Set 5 | bertoua
# Processing Record 26 of Set 5 | havelock
# Processing Record 27 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 5 | hamilton
# Processing Record 29 of Set 5 | nantucket
# Processing Record 30 of Set 5 | tessalit
# Processing Record 31 of Set 5 | villa maria
# Processing Record 32 of Set 5 | oxelosund
# Processing Record 33 of Set 5 | ostersund
# Processing Record 34 of Set 5 | caucaia
# Processing Record 35 of Set 5 | carbonia
# Processing Record 36 of Set 5 | hetauda
# Processing Record 37 of Set 5 | constitucion
# Processing Record 38 of Set 5 | tombouctou
# Processing Record 39 of Set 5 | aswan
# Processing Record 40 of Set 5 | geraldton
# Processing Record 41 of Set 5 | nalut
# Processing Record 42 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 43 of Set 5 | mandera
# Processing Record 44 of Set 5 | seminole
# Processing Record 45 of Set 5 | vardo
# Processing Record 46 of Set 5 | disna
# Processing Record 47 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 5 | alushta
# Processing Record 49 of Set 5 | hun
# Processing Record 50 of Set 5 | buchanan
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | kargopol
# Processing Record 3 of Set 6 | upernavik
# Processing Record 4 of Set 6 | ibipeba
# Processing Record 5 of Set 6 | shelburne
# Processing Record 6 of Set 6 | san cristobal
# Processing Record 7 of Set 6 | roald
# Processing Record 8 of Set 6 | channel-port aux basques
# Processing Record 9 of Set 6 | kedrovyy
# Processing Record 10 of Set 6 | beloha
# Processing Record 11 of Set 6 | funtua
# Processing Record 12 of Set 6 | morondava
# Processing Record 13 of Set 6 | bousso
# Processing Record 14 of Set 6 | novyy urengoy
# Processing Record 15 of Set 6 | westport
# Processing Record 16 of Set 6 | lokosovo
# Processing Record 17 of Set 6 | mubi
# Processing Record 18 of Set 6 | porto walter
# Processing Record 19 of Set 6 | kayerkan
# Processing Record 20 of Set 6 | hanstholm
# Processing Record 21 of Set 6 | gumdag
# Processing Record 22 of Set 6 | goshen
# Processing Record 23 of Set 6 | rundu
# Processing Record 24 of Set 6 | salto
# Processing Record 25 of Set 6 | nara
# Processing Record 26 of Set 6 | hualmay
# Processing Record 27 of Set 6 | aleksandrov gay
# Processing Record 28 of Set 6 | ormara
# Processing Record 29 of Set 6 | gayeri
# Processing Record 30 of Set 6 | munchberg
# Processing Record 31 of Set 6 | mabaruma
# Processing Record 32 of Set 6 | vieux-habitants
# Processing Record 33 of Set 6 | luis correia
# Processing Record 34 of Set 6 | le vauclin
# Processing Record 35 of Set 6 | vieques
# Processing Record 36 of Set 6 | ostrovnoy
# Processing Record 37 of Set 6 | presidencia roque saenz pena
# Processing Record 38 of Set 6 | coquimbo
# Processing Record 39 of Set 6 | guarda
# Processing Record 40 of Set 6 | denizli
# Processing Record 41 of Set 6 | asuncion
# Processing Record 42 of Set 6 | namwala
# Processing Record 43 of Set 6 | abu samrah
# Processing Record 44 of Set 6 | oktyabrskiy
# Processing Record 45 of Set 6 | mbour
# Processing Record 46 of Set 6 | belmonte
# Processing Record 47 of Set 6 | buraydah
# Processing Record 48 of Set 6 | horki
# Processing Record 49 of Set 6 | moen
# Processing Record 50 of Set 6 | nuuk
# Processing Record 1 of Set 7 | jadu
# Processing Record 2 of Set 7 | scarborough
# Processing Record 3 of Set 7 | longyearbyen
# Processing Record 4 of Set 7 | goure
# Processing Record 5 of Set 7 | gachala
# Processing Record 6 of Set 7 | hofn
# Processing Record 7 of Set 7 | hauterive
# Processing Record 8 of Set 7 | dehloran
# Processing Record 9 of Set 7 | selb
# Processing Record 10 of Set 7 | mezen
# Processing Record 11 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 13 of Set 7 | port shepstone
# Processing Record 14 of Set 7 | ayni
# Processing Record 15 of Set 7 | cham
# Processing Record 16 of Set 7 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 17 of Set 7 | zarand
# Processing Record 18 of Set 7 | bukama
# Processing Record 19 of Set 7 | road town
# Processing Record 20 of Set 7 | sabla
# Processing Record 21 of Set 7 | sirpur
# Processing Record 22 of Set 7 | kibala
# Processing Record 23 of Set 7 | surt
# Processing Record 24 of Set 7 | moncao
# Processing Record 25 of Set 7 | gat
# Processing Record 26 of Set 7 | springdale
# Processing Record 27 of Set 7 | sorland
# Processing Record 28 of Set 7 | upington
# Processing Record 29 of Set 7 | bedele
# Processing Record 30 of Set 7 | sakakah
# Processing Record 31 of Set 7 | rafaela
# Processing Record 32 of Set 7 | ayagoz
# Processing Record 33 of Set 7 | rawson
# Processing Record 34 of Set 7 | sao sebastiao
# Processing Record 35 of Set 7 | maroantsetra
# Processing Record 36 of Set 7 | nandikotkur
# Processing Record 37 of Set 7 | oyem
# Processing Record 38 of Set 7 | plettenberg bay
# Processing Record 39 of Set 7 | yar-sale
# Processing Record 40 of Set 7 | valparaiso
# Processing Record 41 of Set 7 | benicarlo
# Processing Record 42 of Set 7 | narsaq
# Processing Record 43 of Set 7 | defiance
# Processing Record 44 of Set 7 | umm kaddadah
# Processing Record 45 of Set 7 | junnar
# Processing Record 46 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 47 of Set 7 | bonthe
# Processing Record 48 of Set 7 | vreed en hoop
# City not found. Skipping...
# Processing Record 49 of Set 7 | bogo
# Processing Record 50 of Set 7 | gharo
# Processing Record 1 of Set 8 | korla
# Processing Record 2 of Set 8 | sozimskiy
# Processing Record 3 of Set 8 | royan
# Processing Record 4 of Set 8 | najran
# Processing Record 5 of Set 8 | forio
# Processing Record 6 of Set 8 | bekhtery
# Processing Record 7 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 8 | vondrozo
# Processing Record 9 of Set 8 | nisia floresta
# Processing Record 10 of Set 8 | zadonsk
# Processing Record 11 of Set 8 | kango
# Processing Record 12 of Set 8 | mecca
# Processing Record 13 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 8 | bereznik
# Processing Record 15 of Set 8 | ordu
# Processing Record 16 of Set 8 | galdar
# Processing Record 17 of Set 8 | wagar
# Processing Record 18 of Set 8 | maniitsoq
# Processing Record 19 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 8 | yahotyn
# Processing Record 21 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 8 | hambantota
# Processing Record 23 of Set 8 | opuwo
# Processing Record 24 of Set 8 | kumo
# Processing Record 25 of Set 8 | veraval
# Processing Record 26 of Set 8 | nova prata
# Processing Record 27 of Set 8 | itarema
# Processing Record 28 of Set 8 | campos gerais
# Processing Record 29 of Set 8 | puerto ayora
# Processing Record 30 of Set 8 | bengkulu
# Processing Record 31 of Set 8 | vila do maio
# Processing Record 32 of Set 8 | nova olimpia
# Processing Record 33 of Set 8 | mitu
# Processing Record 34 of Set 8 | mehran
# Processing Record 35 of Set 8 | quthing
# Processing Record 36 of Set 8 | tokmak
# Processing Record 37 of Set 8 | antalaha
# Processing Record 38 of Set 8 | rogatica
# Processing Record 39 of Set 8 | pitsunda
# Processing Record 40 of Set 8 | aden
# Processing Record 41 of Set 8 | sindgi
# Processing Record 42 of Set 8 | wampusirpi
# City not found. Skipping...
# Processing Record 43 of Set 8 | humaita
# Processing Record 44 of Set 8 | sambava
# Processing Record 45 of Set 8 | zhezkazgan
# Processing Record 46 of Set 8 | lucea
# Processing Record 47 of Set 8 | puerto baquerizo moreno
# Processing Record 48 of Set 8 | bangassou
# Processing Record 49 of Set 8 | santa maria
# Processing Record 50 of Set 8 | saint-louis
# Processing Record 1 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 9 | gualaquiza
# Processing Record 3 of Set 9 | karpathos
# Processing Record 4 of Set 9 | mazagao
# Processing Record 5 of Set 9 | imbituba
# Processing Record 6 of Set 9 | skegness
# Processing Record 7 of Set 9 | san juan
# Processing Record 8 of Set 9 | triolet
# Processing Record 9 of Set 9 | norwich
# Processing Record 10 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 9 | dortyol
# Processing Record 12 of Set 9 | naujamiestis
# Processing Record 13 of Set 9 | ballina
# Processing Record 14 of Set 9 | saint augustine
# Processing Record 15 of Set 9 | ambilobe
# Processing Record 16 of Set 9 | praia da vitoria
# Processing Record 17 of Set 9 | ancud
# Processing Record 18 of Set 9 | andenes
# Processing Record 19 of Set 9 | manaus
# Processing Record 20 of Set 9 | crossville
# Processing Record 21 of Set 9 | saint pete beach
# Processing Record 22 of Set 9 | godhra
# Processing Record 23 of Set 9 | nouadhibou
# Processing Record 24 of Set 9 | havre-saint-pierre
# Processing Record 25 of Set 9 | inta
# Processing Record 26 of Set 9 | zherdevka
# Processing Record 27 of Set 9 | maceio
# Processing Record 28 of Set 9 | sao raimundo nonato
# Processing Record 29 of Set 9 | johnson city
# Processing Record 30 of Set 9 | beisfjord
# Processing Record 31 of Set 9 | huesca
# Processing Record 32 of Set 9 | tucuma
# Processing Record 33 of Set 9 | camacha
# Processing Record 34 of Set 9 | diamantino
# Processing Record 35 of Set 9 | cavalcante
# Processing Record 36 of Set 9 | lukulu
# Processing Record 37 of Set 9 | vargashi
# Processing Record 38 of Set 9 | bumba
# Processing Record 39 of Set 9 | old saybrook
# Processing Record 40 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 41 of Set 9 | antalya
# Processing Record 42 of Set 9 | kattivakkam
# Processing Record 43 of Set 9 | cacoal
# Processing Record 44 of Set 9 | aragarcas
# Processing Record 45 of Set 9 | san matias
# Processing Record 46 of Set 9 | ornskoldsvik
# Processing Record 47 of Set 9 | boa vista
# Processing Record 48 of Set 9 | vetluga
# Processing Record 49 of Set 9 | bam
# Processing Record 50 of Set 9 | arak
# Processing Record 1 of Set 10 | kidal
# Processing Record 2 of Set 10 | mangrol
# Processing Record 3 of Set 10 | chabahar
# Processing Record 4 of Set 10 | oranjestad
# Processing Record 5 of Set 10 | port-cartier
# Processing Record 6 of Set 10 | maarianhamina
# Processing Record 7 of Set 10 | natal
# Processing Record 8 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 9 of Set 10 | keuruu
# Processing Record 10 of Set 10 | zdvinsk
# Processing Record 11 of Set 10 | nikolskoye
# Processing Record 12 of Set 10 | sindor
# Processing Record 13 of Set 10 | tamandare
# Processing Record 14 of Set 10 | vila franca do campo
# Processing Record 15 of Set 10 | porto santo
# Processing Record 16 of Set 10 | catamarca
# Processing Record 17 of Set 10 | nouakchott
# Processing Record 18 of Set 10 | lesnyye polyany
# Processing Record 19 of Set 10 | pizarro
# Processing Record 20 of Set 10 | lerwick
# Processing Record 21 of Set 10 | lulea
# Processing Record 22 of Set 10 | eidsvag
# Processing Record 23 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 10 | huarmey
# Processing Record 25 of Set 10 | castelo do piaui
# Processing Record 26 of Set 10 | samana
# Processing Record 27 of Set 10 | rabo de peixe
# Processing Record 28 of Set 10 | kostomuksha
# Processing Record 29 of Set 10 | grindavik
# Processing Record 30 of Set 10 | tibu
# Processing Record 31 of Set 10 | gornopravdinsk
# Processing Record 32 of Set 10 | halifax
# Processing Record 33 of Set 10 | mastaga
# Processing Record 34 of Set 10 | jaffna
# Processing Record 35 of Set 10 | aras
# Processing Record 36 of Set 10 | makueni
# Processing Record 37 of Set 10 | mamallapuram
# Processing Record 38 of Set 10 | sahbuz
# Processing Record 39 of Set 10 | wick
# Processing Record 40 of Set 10 | viedma
# Processing Record 41 of Set 10 | mumford
# Processing Record 42 of Set 10 | alto paraguai
# Processing Record 43 of Set 10 | saint-dizier
# Processing Record 44 of Set 10 | kissidougou
# Processing Record 45 of Set 10 | makurdi
# Processing Record 46 of Set 10 | kibre mengist
# Processing Record 47 of Set 10 | pangody
# Processing Record 48 of Set 10 | mantua
# Processing Record 49 of Set 10 | turtas
# Processing Record 50 of Set 10 | rocha
# Processing Record 1 of Set 11 | yanam
# Processing Record 2 of Set 11 | kem
# Processing Record 3 of Set 11 | cockburn town
# Processing Record 4 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 11 | ji-parana
# City not found. Skipping...
# Processing Record 6 of Set 11 | peniche
# Processing Record 7 of Set 11 | areka
# Processing Record 8 of Set 11 | faya
# Processing Record 9 of Set 11 | palaikastron
# Processing Record 10 of Set 11 | dorado
# Processing Record 11 of Set 11 | stary plzenec
# Processing Record 12 of Set 11 | mahanje
# Processing Record 13 of Set 11 | tabat
# Processing Record 14 of Set 11 | veendam
# Processing Record 15 of Set 11 | tiszaroff
# Processing Record 16 of Set 11 | cururupu
# Processing Record 17 of Set 11 | leh
# Processing Record 18 of Set 11 | arkhangelos
# City not found. Skipping...
# Processing Record 19 of Set 11 | maragogi
# Processing Record 20 of Set 11 | zambezi
# Processing Record 21 of Set 11 | tucurui
# Processing Record 22 of Set 11 | saint-georges
# Processing Record 23 of Set 11 | paamiut
# Processing Record 24 of Set 11 | oksfjord
# Processing Record 25 of Set 11 | port-gentil
# Processing Record 26 of Set 11 | ibatiba
# Processing Record 27 of Set 11 | luderitz
# Processing Record 28 of Set 11 | beira
# Processing Record 29 of Set 11 | la sarre
# Processing Record 30 of Set 11 | piranshahr
# Processing Record 31 of Set 11 | zaykovo
# Processing Record 32 of Set 11 | benoy
# Processing Record 33 of Set 11 | naantali
# Processing Record 34 of Set 11 | novobelokatay
# Processing Record 35 of Set 11 | batticaloa
# Processing Record 36 of Set 11 | cotonou
# Processing Record 37 of Set 11 | mattru
# Processing Record 38 of Set 11 | bat khela
# Processing Record 39 of Set 11 | pipili
# Processing Record 40 of Set 11 | wicklow
# Processing Record 41 of Set 11 | doha
# Processing Record 42 of Set 11 | parabel
# Processing Record 43 of Set 11 | hammerfest
# Processing Record 44 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 11 | saint-pierre
# Processing Record 46 of Set 11 | mogadishu
# Processing Record 47 of Set 11 | quilmana
# Processing Record 48 of Set 11 | mwaya
# Processing Record 49 of Set 11 | aripuana
# Processing Record 50 of Set 11 | jimma
# Processing Record 1 of Set 12 | herat
# Processing Record 2 of Set 12 | kemijarvi
# Processing Record 3 of Set 12 | terra santa
# Processing Record 4 of Set 12 | usinsk
# Processing Record 5 of Set 12 | rovaniemi
# Processing Record 6 of Set 12 | conceicao do araguaia
# Processing Record 7 of Set 12 | grenaa
# Processing Record 8 of Set 12 | capinota
# Processing Record 9 of Set 12 | sortland
# Processing Record 10 of Set 12 | verkhnetulomskiy
# Processing Record 11 of Set 12 | constantine
# Processing Record 12 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 12 | saint-jean-de-luz
# Processing Record 14 of Set 12 | bembereke
# Processing Record 15 of Set 12 | elliot lake
# Processing Record 16 of Set 12 | kilinochchi
# Processing Record 17 of Set 12 | dokka
# Processing Record 18 of Set 12 | bud
# Processing Record 19 of Set 12 | owensboro
# Processing Record 20 of Set 12 | tarata
# Processing Record 21 of Set 12 | ferkessedougou
# Processing Record 22 of Set 12 | kerekegyhaza
# Processing Record 23 of Set 12 | isfara
# Processing Record 24 of Set 12 | pesnica pri mariboru
# Processing Record 25 of Set 12 | oron
# Processing Record 26 of Set 12 | bayji
# Processing Record 27 of Set 12 | fernandina beach
# Processing Record 28 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 12 | huntingdon
# Processing Record 30 of Set 12 | sabzevar
# Processing Record 31 of Set 12 | sao joao do paraiso
# Processing Record 32 of Set 12 | yerani
# City not found. Skipping...
# Processing Record 33 of Set 12 | mattawa
# Processing Record 34 of Set 12 | togur
# Processing Record 35 of Set 12 | pangnirtung
# Processing Record 36 of Set 12 | vagur
# Processing Record 37 of Set 12 | hasanabad
# Processing Record 38 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 12 | adilabad
# Processing Record 40 of Set 12 | ust-kan
# Processing Record 41 of Set 12 | sisimiut
# Processing Record 42 of Set 12 | sikeston
# Processing Record 43 of Set 12 | karpogory
# Processing Record 44 of Set 12 | killybegs
# Processing Record 45 of Set 12 | kangaatsiaq
# Processing Record 46 of Set 12 | minsk
# Processing Record 47 of Set 12 | thompson
# Processing Record 48 of Set 12 | marathon
# Processing Record 49 of Set 12 | atar
# Processing Record 50 of Set 12 | yarmouth
# Processing Record 1 of Set 13 | bogotol
# Processing Record 2 of Set 13 | povenets
# Processing Record 3 of Set 13 | conselheiro lafaiete
# Processing Record 4 of Set 13 | mobai
# Processing Record 5 of Set 13 | kousseri
# Processing Record 6 of Set 13 | sao paulo de olivenca
# Processing Record 7 of Set 13 | deer lake
# Processing Record 8 of Set 13 | staraya poltavka
# Processing Record 9 of Set 13 | abha
# Processing Record 10 of Set 13 | garissa
# Processing Record 11 of Set 13 | filingue
# Processing Record 12 of Set 13 | rio gallegos
# Processing Record 13 of Set 13 | sibi
# Processing Record 14 of Set 13 | am timan
# Processing Record 15 of Set 13 | necochea
# Processing Record 16 of Set 13 | sabha
# Processing Record 17 of Set 13 | galle
# Processing Record 18 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 19 of Set 13 | carmarthen
# Processing Record 20 of Set 13 | nahrin
# Processing Record 21 of Set 13 | vestmanna
# Processing Record 22 of Set 13 | yerkoy
# Processing Record 23 of Set 13 | beyneu
# Processing Record 24 of Set 13 | chake chake
# Processing Record 25 of Set 13 | los llanos de aridane
# Processing Record 26 of Set 13 | morros
# Processing Record 27 of Set 13 | matagami
# Processing Record 28 of Set 13 | thinadhoo
# Processing Record 29 of Set 13 | aksay
# Processing Record 30 of Set 13 | itanhem
# Processing Record 31 of Set 13 | chute-aux-outardes
# Processing Record 32 of Set 13 | kuryk
# Processing Record 33 of Set 13 | tripoli
# Processing Record 34 of Set 13 | oranjemund
# Processing Record 35 of Set 13 | port hawkesbury
# Processing Record 36 of Set 13 | kamenka
# Processing Record 37 of Set 13 | placido de castro
# Processing Record 38 of Set 13 | ayabaca
# Processing Record 39 of Set 13 | selty
# Processing Record 40 of Set 13 | ndele
# Processing Record 41 of Set 13 | petauke
# Processing Record 42 of Set 13 | semme
# Processing Record 43 of Set 13 | mehriz
# Processing Record 44 of Set 13 | buzdyak
# Processing Record 45 of Set 13 | chulym
# Processing Record 46 of Set 13 | umea
# Processing Record 47 of Set 13 | taltal
# Processing Record 48 of Set 13 | samoylovka
# Processing Record 49 of Set 13 | conthey
# Processing Record 50 of Set 13 | pleshanovo
# Processing Record 1 of Set 14 | tandil
# Processing Record 2 of Set 14 | kontagora
# Processing Record 3 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 4 of Set 14 | aleksandrovka
# Processing Record 5 of Set 14 | terrace bay
# Processing Record 6 of Set 14 | senanga
# Processing Record 7 of Set 14 | janakpur
# Processing Record 8 of Set 14 | benguela
# Processing Record 9 of Set 14 | waverly
# Processing Record 10 of Set 14 | fort-shevchenko
# Processing Record 11 of Set 14 | ust-ishim
# Processing Record 12 of Set 14 | potosi
# Processing Record 13 of Set 14 | molodizhne
# Processing Record 14 of Set 14 | nhamunda
# Processing Record 15 of Set 14 | riaba
# City not found. Skipping...
# Processing Record 16 of Set 14 | rasra
# Processing Record 17 of Set 14 | yangambi
# Processing Record 18 of Set 14 | thunder bay
# Processing Record 19 of Set 14 | borgarnes
# Processing Record 20 of Set 14 | koygorodok
# Processing Record 21 of Set 14 | bay city
# Processing Record 22 of Set 14 | moose factory
# Processing Record 23 of Set 14 | lapeer
# Processing Record 24 of Set 14 | bolgatanga
# Processing Record 25 of Set 14 | le port
# Processing Record 26 of Set 14 | lyubeshiv
# City not found. Skipping...
# Processing Record 27 of Set 14 | vasarosnameny
# Processing Record 28 of Set 14 | maloy
# Processing Record 29 of Set 14 | sept-iles
# Processing Record 30 of Set 14 | venice
# Processing Record 31 of Set 14 | goderich
# Processing Record 32 of Set 14 | awjilah
# Processing Record 33 of Set 14 | barreirinha
# Processing Record 34 of Set 14 | oistins
# Processing Record 35 of Set 14 | ambalavao
# Processing Record 36 of Set 14 | koani
# Processing Record 37 of Set 14 | salamiyah
# Processing Record 38 of Set 14 | cassilandia
# Processing Record 39 of Set 14 | jacareacanga
# Processing Record 40 of Set 14 | liwale
# Processing Record 41 of Set 14 | irondequoit
# Processing Record 42 of Set 14 | riberalta
# Processing Record 43 of Set 14 | kilindoni
# Processing Record 44 of Set 14 | jumla
# Processing Record 45 of Set 14 | bridgetown
# Processing Record 46 of Set 14 | marsh harbour
# Processing Record 47 of Set 14 | aksarka
# Processing Record 48 of Set 14 | abalak
# Processing Record 49 of Set 14 | cravo norte
# Processing Record 50 of Set 14 | kuytun
# Processing Record 1 of Set 15 | kudahuvadhoo
# Processing Record 2 of Set 15 | axim
# Processing Record 3 of Set 15 | zharkent
# Processing Record 4 of Set 15 | linares
# Processing Record 5 of Set 15 | atasu
# Processing Record 6 of Set 15 | syracuse
# Processing Record 7 of Set 15 | vamvakou
# Processing Record 8 of Set 15 | lubango
# Processing Record 9 of Set 15 | adwa
# Processing Record 10 of Set 15 | chaumont
# Processing Record 11 of Set 15 | bonanza
# Processing Record 12 of Set 15 | la brea
# Processing Record 13 of Set 15 | soyo
# Processing Record 14 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 15 | lodwar
# Processing Record 16 of Set 15 | dedovichi
# Processing Record 17 of Set 15 | nacala
# Processing Record 18 of Set 15 | nizwa
# Processing Record 19 of Set 15 | kikerino
# Processing Record 20 of Set 15 | copiapo
# Processing Record 21 of Set 15 | rio grande
# Processing Record 22 of Set 15 | falmouth
# Processing Record 23 of Set 15 | wickede
# Processing Record 24 of Set 15 | areosa
# Processing Record 25 of Set 15 | maralal
# Processing Record 26 of Set 15 | mazyr
# Processing Record 27 of Set 15 | arroyo
# Processing Record 28 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 29 of Set 15 | jizan
# Processing Record 30 of Set 15 | kashi
# Processing Record 31 of Set 15 | bijawar
# Processing Record 32 of Set 15 | emba
# Processing Record 33 of Set 15 | tirano
# Processing Record 34 of Set 15 | dogondoutchi
# Processing Record 35 of Set 15 | abbeville
# Processing Record 36 of Set 15 | shar
# Processing Record 37 of Set 15 | urucui
# Processing Record 38 of Set 15 | skvyra
# Processing Record 39 of Set 15 | kamra
# Processing Record 40 of Set 15 | villanueva de la serena
# Processing Record 41 of Set 15 | edd
# Processing Record 42 of Set 15 | voiron
# Processing Record 43 of Set 15 | puerto gaitan
# Processing Record 44 of Set 15 | houma
# Processing Record 45 of Set 15 | toktogul
# Processing Record 46 of Set 15 | krasnozerskoye
# Processing Record 47 of Set 15 | abnub
# Processing Record 48 of Set 15 | arys
# Processing Record 49 of Set 15 | igdir
# Processing Record 50 of Set 15 | capao da canoa
# Processing Record 1 of Set 16 | letnik
# Processing Record 2 of Set 16 | bull savanna
# Processing Record 3 of Set 16 | kralendijk
# Processing Record 4 of Set 16 | pascagoula
# Processing Record 5 of Set 16 | muisne
# Processing Record 6 of Set 16 | micheweni
# Processing Record 7 of Set 16 | spanish town
# Processing Record 8 of Set 16 | reading
# Processing Record 9 of Set 16 | ugoofaaru
# Processing Record 10 of Set 16 | borovoy
# Processing Record 11 of Set 16 | bahia blanca
# Processing Record 12 of Set 16 | stephenville
# Processing Record 13 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 16 | panjab
# Processing Record 15 of Set 16 | undory
# Processing Record 16 of Set 16 | charlestown
# Processing Record 17 of Set 16 | marystown
# Processing Record 18 of Set 16 | santiago de compostela
# Processing Record 19 of Set 16 | muscle shoals
# Processing Record 20 of Set 16 | melnikovo
# Processing Record 21 of Set 16 | lumeje
# Processing Record 22 of Set 16 | tabarqah
# City not found. Skipping...
# Processing Record 23 of Set 16 | libreville
# Processing Record 24 of Set 16 | bako
# Processing Record 25 of Set 16 | yafran
# Processing Record 26 of Set 16 | itupiranga
# Processing Record 27 of Set 16 | daugai
# Processing Record 28 of Set 16 | akureyri
# Processing Record 29 of Set 16 | bisho
# Processing Record 30 of Set 16 | bedford
# Processing Record 31 of Set 16 | cumbitara
# Processing Record 32 of Set 16 | manica
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 728

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Joigny  47.9829    3.4010     29.80        87          99        3.65
# 1      Ushuaia -54.8000  -68.3000     46.06        61          40       24.16
# 2       Castro -24.7911  -50.0119     65.26        96          69       11.05
# 3      Qaanaaq  77.4840  -69.3632      1.89        93         100        5.39
# 4        Wamba   8.9333    8.6000     73.78        29          19        4.03
# 5    Raudeberg  61.9875    5.1352     26.87        73         100        8.25
# 6  Henties Bay -22.1160   14.2845     61.65        93          99        1.97
# 7      Yenagoa   4.9247    6.2642     77.34        84          13        4.05
# 8     Victoria  22.2855  114.1577     55.26        92         100       15.01
# 9   Bredasdorp -34.5322   20.0403     67.66        86          42        1.34
#
#   Country Weather Description
# 0      FR     overcast clouds
# 1      AR    scattered clouds
# 2      BR       broken clouds
# 3      GL     overcast clouds
# 4      NG          few clouds
# 5      NO          light snow
# 6      NA     overcast clouds
# 7      NG          few clouds
# 8      HK     overcast clouds
# 9      ZA    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
columns_reorganized = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[columns_reorganized]

# Display sample data
city_data_df.head()
# Out:
#       City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   Joigny      FR  47.9829   3.4010     29.80        87          99
# 1  Ushuaia      AR -54.8000 -68.3000     46.06        61          40
# 2   Castro      BR -24.7911 -50.0119     65.26        96          69
# 3  Qaanaaq      GL  77.4840 -69.3632      1.89        93         100
# 4    Wamba      NG   8.9333   8.6000     73.78        29          19
#
#    Wind Speed Weather Description
# 0        3.65     overcast clouds
# 1       24.16    scattered clouds
# 2       11.05       broken clouds
# 3        5.39     overcast clouds
# 4        4.03          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 728 non-null    object
#  1   Country              728 non-null    object
#  2   Lat                  728 non-null    float64
#  3   Lng                  728 non-null    float64
#  4   Max Temp             728 non-null    float64
#  5   Humidity             728 non-null    int64
#  6   Cloudiness           728 non-null    int64
#  7   Wind Speed           728 non-null    float64
#  8   Weather Description  728 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 51.3+ KB

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
export_file = '../Weather_database/WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(export_file, index_label='City_ID')
